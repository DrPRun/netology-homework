# %% [markdown]
# # Задание №1

# %%
import pandas as pd
import numpy as np
import re
from pymystem3 import Mystem
log = pd.read_csv('/Users/ruslanpepa/Netology/netology-classrom/доп_материалы_к_пандас_1_и_2/visit_log.csv', sep = ';')
log.head(100)
# Out:
#      timestamp    visit_id                                 url   region  \
# 0   1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3   Russia
# 1   1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a   Russia
# 2   1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15   Russia
# 3   1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15   Russia
# 4   1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15   Russia
# ..         ...         ...                                 ...      ...
# 95  1549981294  8542681424  https://host.ru/f1eb4601740d627ab0   Russia
# 96  1549981298  2ea9ab9198  https://host.ru/9f90e5c423a5f976d4  Ukraine
# 97  1549981308  136dd1a7d0  https://host.ru/1be58f19f26458f2fe   Russia
# 98  1549981312  30274f1a3e  https://host.ru/5301a605bd574af1a5   Russia
# 99  1549981324  4b298058e1  https://host.ru/b8b58337d272ee7b15  Belarus
#
#        user_id traffic_source
# 0   b1613cc09f         yandex
# 1   4c3ec14bee         direct
# ...

# %%
log['source_type'] = log.apply(lambda row: 'organic' if ('yandex' in row.traffic_source) or ( 'google' in row.traffic_source ) else None, axis = 1)
log['source_type'] = log.apply(lambda row: 'ad' if (('paid' in row.traffic_source) or ('email' in row.traffic_source)) and row.region == 'Russia' else row.source_type, axis = 1)
log['source_type'] = log.apply(lambda row: 'other' if (('paid' in row.traffic_source) or ('email' in row.traffic_source)) and row.region != 'Russia' else row.source_type, axis = 1)
log['source_type'] = log.apply(lambda row: row.traffic_source if row.source_type == None else row.source_type, axis = 1)
# log['source_type'] = log.apply(lambda row: 'other' if (('paid' in row.traffic_source) or ('email' in log.traffic_source)) and row.region != 'Russia' else None, axis = 1)
log.head(50)
# Out:
#      timestamp    visit_id                                 url   region  \
# 0   1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3   Russia
# 1   1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a   Russia
# 2   1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15   Russia
# 3   1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15   Russia
# 4   1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15   Russia
# 5   1549980742  8855508aad  https://host.ru/df646c3676cc259fa0   Russia
# 6   1549980742  b0f66adc83  https://host.ru/b8b58337d272ee7b15   Russia
# 7   1549980754  837885c8f8  https://host.ru/108ce4b365afb7b88e   Russia
# 8   1549980760  af5570f5a1  https://host.ru/3004a8273caeef2867    China
# 9   1549980765  3e7077fd2f  https://host.ru/df646c3676cc259fa0   Russia
# 10  1549980777  01d448afd9  https://host.ru/a5dda93e70318570c0    India
# 11  1549980785  71b6c1d538  https://host.ru/c8d9213a31839f9a3a  Ukraine
# ...

# %% [markdown]
# # Задание № 2

# %%
urltxt = pd.read_csv('/Users/ruslanpepa/Netology/netology-classrom/доп_материалы_к_пандас_1_и_2/URLs.txt')

# %%
urltxt.head(100)
# Out:
#                                                   url
# 0                                             /world/
# 1                                            /latest/
# 2                                       /?updated=top
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# ..                                                ...
# 88  /cis/35984145-kreml-prokommentiroval-soobschen...
# 89  /video/36071019-olimpiyskie-obekty-rio-prevrat...
# 90  /science/36151301-nazvano-posledstvie-zloupotr...
# 91  /incidents/36027330-vospitatelnitsu-zatravili-...
# 92  /world/36103095-dominikanskih-zhurnalistov-ubi...
#
# [93 rows x 1 columns]

# %%
urltxt.loc[urltxt.url.str.contains(r'/\d{8}-')].head()
# Out:
#                                                  url
# 3  /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4  /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5  /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6  /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7  /world/36007585-tramp-pridumal-kak-reshit-ukra...

# %% [markdown]
# # Задание 3

# %%
new_dataframe = pd.read_csv('/Users/ruslanpepa/Netology/netology-classrom/доп_материалы_к_пандас_1_и_2/ml-latest-small/ratings.csv')
dfrctn = new_dataframe.groupby('userId').count().reset_index().loc[dfrctn.movieId >= 100] # группируем по пользователем
# dfrctn.loc[dfrctn.movieId >= 100].head(50) # фильтруем от тех фильмов, количество оценок которым меньше 100
dfrctn['timelife'] = dfrctn.apply(lambda row:  (new_dataframe[new_dataframe['userId'] == row['userId']].max() - new_dataframe[new_dataframe['userId'] == row['userId']].min())['timestamp'], axis = 1 )


dfrctn.head(50)
# Out:
#      userId  movieId  rating  timestamp     timelife
# 3         4      204     204        204     203560.0
# 4         5      100     100        100       2101.0
# 7         8      116     116        116      85187.0
# 14       15     1700    1700       1700  471393496.0
# 16       17      363     363        363       8053.0
# 18       19      423     423        423       5282.0
# 20       21      162     162        162    1365432.0
# 21       22      220     220        220      91491.0
# 22       23      726     726        726   18342129.0
# 25       26      172     172        172   20267261.0
# 29       30     1011    1011       1011  115852276.0
# 32       33      138     138        138    4332211.0
# 33       34      187     187        187       2835.0
# 35       36      104     104        104    5949290.0
# 37       38      111     111        111   59971665.0
# 40       41      199     199        199   15930495.0
# 42       43      110     110        110      13885.0
# ...

# %% [markdown]
# # Задание 4

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %%
joi = air.merge(rzd, how = 'outer', on ='client_id' )
air_rzd_auto = joi.merge(auto, how = 'outer', on = 'client_id')
air_rzd_auto.head(10)
# Out:
#    client_id  air_revenue  rzd_revenue  auto_revenue
# 0        115         81.0        981.0         912.0
# 1        116          4.0          NaN        4834.0
# 2        117         13.0          NaN          98.0
# 3        118        173.0          NaN           NaN
# 4        111          NaN       1093.0           NaN
# 5        112          NaN       2810.0           NaN
# 6        113          NaN      10283.0       57483.0
# 7        114          NaN       5774.0          83.0
