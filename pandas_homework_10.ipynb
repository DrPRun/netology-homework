# %% [markdown]
# # Задание № 1

# %%
import pandas as pd

# %%
tags.csv
README.txt
ratings.csv
movies.csv
links.csv
genome-tags.csv
genome-scores.csv

# %%
data_movies = pd.read_csv('movies.csv')
data_tags = pd.read_csv('tags.csv')
data_rating = pd.read_csv('ratings.csv')
data_links = pd.read_csv('links.csv')
data_gtags = pd.read_csv('genome-tags.csv')
data_power = pd.read_csv('power.csv')

# %%
# data_rating[data_rating['rating']== 5.0].sort_values(by='movieId').head(50)
dt_rating = data_rating.filter(items = ['movieId', 'rating'])
dt_rating[dt_rating['rating']==5.0].sort_values(by='movieId').value_counts().head(50)
# Out:
# movieId  rating
# 318      5.0       48762
# 296      5.0       37458
# 356      5.0       32009
# 260      5.0       31385
# 593      5.0       30280
# 527      5.0       30194
# 2571     5.0       30126
# 858      5.0       28893
# 50       5.0       24679
# 2959     5.0       24366
# 1196     5.0       24139
# 110      5.0       22369
# 4993     5.0       21059
# 1198     5.0       20854
# 2858     5.0       20133
# 7153     5.0       19404
# 1210     5.0       19191
# 608      5.0       18616
# 5952     5.0       17918
# 589      5.0       16616
# 1        5.0       16497
# 1221     5.0       16387
# 2028     5.0       16084
# 47       5.0       15286
# 1197     5.0       15259
# 1193     5.0       14737
# 58559    5.0       14469
# 457      5.0       14047
# 1136     5.0       13810
# 541      5.0       13545
# 150      5.0       13377
# 480      5.0       13311
# 1270     5.0       13267
# 2762     5.0       13022
# 79132    5.0       12715
# 912      5.0       12676
# ...

# %% [markdown]
# # Задание № 2

# %%
data_power.loc[(data_power['country'] == 'Latvia' )   ].sum()
data_power[(data_power['country'] == 'Lithuania' )  ].sum()
data_power[(data_power['country'] == 'Estonia' )  ].sum()
# Out:
# country     EstoniaEstoniaEstoniaEstoniaEstoniaEstoniaEsto...
# year                                                 19409451
# quantity                                      61766648.998905
# category                                               366685
# dtype: object

# %% [markdown]
# # Задание № 3

# %%
pd.read_html('https://fortrader.org/quotes')
# Out:
# [                           Название   Цена  Изменение  Изменение(%)  Обновлено
#  0  EURRUB Курс евро к рублю сегодня  86.16       0.05          0.06        NaN
#  1       USDRUB Курс рубля к доллару  72.20       0.08          0.11        NaN,
#                                Название    Цена  Изменение  Изменение(%)  \
#  0       Нефть Brent Курс нефти сегодня   75.16      -0.32         -0.42
#  1          Нефть WTI Цены на нефть WTI   73.95      -0.20         -0.27
#  2  Природный газ Цена на природный газ    3.53       0.04          1.03
#  3                                 Кофе  159.50       1.60          1.01
#  4                             Кукуруза  643.40       5.80          0.91
#  5                                  Соя  348.50       0.80          0.23
#  6                               Хлопок   87.60       0.42          0.48
#
#     Обновлено
#  0        NaN
#  1        NaN
#  2        NaN
#  3        NaN
#  4        NaN
#  5        NaN
#  6        NaN  ,
# ...
